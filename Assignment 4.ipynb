# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
plt.style.use('seaborn-colorblind')

# %%
Temperature = pd.read_csv('C:/Users/Dell/Desktop/Assignment 6/Temparature.csv')
Temperature.head()
# Out:
#        tas   Year  Month      Country  ISO3
# 0  17.4518   1991      1   Bangladesh   BGD
# 1  21.7874   1991      2   Bangladesh   BGD
# 2  25.9068   1991      3   Bangladesh   BGD
# 3  27.3361   1991      4   Bangladesh   BGD
# 4  27.5258   1991      5   Bangladesh   BGD

# %%
Rainfall = pd.read_csv('C:/Users/Dell/Desktop/Assignment 6/Rainfal.csv')
Rainfall.head()
# Out:
#          pr   Year  Month      Country  ISO3
# 0   15.5629   1991      1   Bangladesh   BGD
# 1   28.3230   1991      2   Bangladesh   BGD
# 2   41.9833   1991      3   Bangladesh   BGD
# 3  195.3100   1991      4   Bangladesh   BGD
# 4  355.5960   1991      5   Bangladesh   BGD

# %%
Monthly_Temp = Temperature.groupby('Month').mean()['tas']
Jan = Monthly_Temp.iloc[0]
Feb = Monthly_Temp.iloc[1]
Mar = Monthly_Temp.iloc[2]
Apr = Monthly_Temp.iloc[3]
May = Monthly_Temp.iloc[4]
Jun = Monthly_Temp.iloc[5]
Jul = Monthly_Temp.iloc[6]
Aug = Monthly_Temp.iloc[7]
Sep = Monthly_Temp.iloc[8]
Oct = Monthly_Temp.iloc[9]
Nov = Monthly_Temp.iloc[10]
Dec = Monthly_Temp.iloc[11]

# %%
Weather = pd.DataFrame({'Temperature': [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]})
Weather
# Out:
#     Temperature
# 0     18.265596
# 1     20.935718
# 2     25.379808
# 3     27.750777
# 4     28.257465
# 5     28.400254
# 6     28.169835
# 7     28.282638
# 8     28.174785
# 9     27.079996
# 10    23.565115
# 11    19.643479

# %%
Monthly_Rain = Rainfall.groupby('Month').mean()['pr']
Monthly_Rain.iloc[0]
Jan = Monthly_Rain.iloc[0]
Feb = Monthly_Rain.iloc[1]
Mar = Monthly_Rain.iloc[2]
Apr = Monthly_Rain.iloc[3]
May = Monthly_Rain.iloc[4]
Jun = Monthly_Rain.iloc[5]
Jul = Monthly_Rain.iloc[6]
Aug = Monthly_Rain.iloc[7]
Sep = Monthly_Rain.iloc[8]
Oct = Monthly_Rain.iloc[9]
Nov = Monthly_Rain.iloc[10]
Dec = Monthly_Rain.iloc[11]

# %%
Weather['Rainfall'] = [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]
Weather
# Out:
#     Temperature    Rainfall
# 0     18.265596    8.225887
# 1     20.935718   19.221967
# 2     25.379808   44.323230
# 3     27.750777  159.585969
# 4     28.257465  250.917115
# 5     28.400254  403.763192
# 6     28.169835  500.053038
# 7     28.282638  419.727577
# 8     28.174785  302.768154
# 9     27.079996  172.719438
# 10    23.565115   28.945723
# 11    19.643479    5.594340

# %%
plt.xlabel('Months')
y1 = Weather['Temperature'].tolist()
y2 = Weather['Rainfall'].tolist()


plt.plot(x, y1, '-s', label = "Temperature (in $\,^{\circ}\mathrm{C}$)")
plt.plot(x, y2, '-o', label = "Rainfall (in 0.1*cm)")

plt.title('Average Temperature and Rainfall in Bangladesh(1991-2016)')
 
plt.legend(frameon=False)
[plt.gca().spines[loc].set_visible(False) for loc in ['top', 'right']]

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Weather.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Weather
# Out:
#      Temperature    Rainfall
# Jan    18.265596    8.225887
# Feb    20.935718   19.221967
# Mar    25.379808   44.323230
# Apr    27.750777  159.585969
# May    28.257465  250.917115
# Jun    28.400254  403.763192
# Jul    28.169835  500.053038
# Aug    28.282638  419.727577
# Sep    28.174785  302.768154
# Oct    27.079996  172.719438
# Nov    23.565115   28.945723
# Dec    19.643479    5.594340
